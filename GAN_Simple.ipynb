# %% [markdown]
# <a href="https://colab.research.google.com/github/ashma01/ashma01/blob/master/GAN_Simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import FashionMNIST
from torchvision.utils import make_grid
import torch.nn.functional as F

# %%
#Load Fashion MNIST data set

mnist = FashionMNIST(root='data', 
              train=True, 
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))

to_pil_image = torchvision.transforms.ToPILImage()

# %%
img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  9
# tensor([[[-1.0000, -1.0000, -1.0000,  0.5137,  0.7882],
#          [-0.9765, -1.0000, -0.9059,  0.7176,  0.7255],
#          [-0.9529, -1.0000, -0.2235,  0.9137,  0.7412],
#          [-1.0000, -1.0000, -0.5686,  0.8510,  0.7882],
#          [-1.0000, -1.0000,  0.8588,  0.7725,  0.7020]]])
# (tensor(-1.), tensor(1.))

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 9

# %%
from torch.utils.data import DataLoader

#Data loader
batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([7, 8, 9, 2, 3, 9, 5, 8, 2, 4, 9, 9, 8, 5, 2, 9, 2, 7, 9, 9, 8, 9, 6, 6,
#         7, 5, 0, 7, 1, 9, 1, 7, 0, 7, 1, 5, 7, 0, 3, 3, 0, 5, 9, 9, 2, 4, 5, 4,
#         4, 9, 6, 7, 9, 9, 0, 8, 0, 9, 9, 4, 4, 0, 9, 8, 2, 4, 9, 7, 5, 0, 3, 7,
#         9, 0, 2, 5, 1, 6, 6, 9, 3, 7, 5, 2, 2, 6, 1, 5, 8, 0, 4, 6, 4, 0, 1, 1,
#         8, 1, 0, 0])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cpu')

# %%
#Discriminator networ parameter
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn

# #Discriminator
class Discriminator(nn.Module):
  def __init__(self, image_size, hidden_size):
    super(Discriminator, self).__init__()

    self.fc1 = nn.Linear(image_size, hidden_size)
    self.fc2 = nn.Linear(hidden_size, hidden_size)
    self.fc3 = nn.Linear(hidden_size, 1)
    self.sig = nn.Sigmoid()

  def forward(self, x):
     x = F.leaky_relu(self.fc1(x), 0.2)  
     x = F.leaky_relu(self.fc2(x), 0.2)  
     out = self.sig(self.fc3(x))
     return out


# Discriminator = nn.Sequential(
#     nn.Linear(image_size, hidden_size),
#     nn.LeakyReLU(0.2),
#     nn.Linear(hidden_size, hidden_size),
#     nn.LeakyReLU(0.2),
#     nn.Linear(hidden_size, 1),
#     nn.Sigmoid())


Discriminator_model = Discriminator(image_size, hidden_size)

# %%
#Generator network parameter
latent_size = 64

# Generator = nn.Sequential(
#     nn.Linear(latent_size, hidden_size),
#     nn.ReLU(),
#     nn.Linear(hidden_size, hidden_size),
#     nn.ReLU(),
#     nn.Linear(hidden_size, image_size),
#     nn.Tanh())


# Generator.to(device);

class Generator(nn.Module):
  def __init__(self, latent_size, hidden_size, image_size):
    super(Generator, self).__init__()
    
    self.fc1 = nn.Linear(latent_size, hidden_size)
    self.fc2 = nn.Linear(hidden_size, hidden_size)
    self.fc3 = nn.Linear(hidden_size, image_size)
    self.tanh = nn.Tanh()
    
  def forward(self, x):
    # 4
    x = F.relu(self.fc1(x), 0.2) # (input, negative_slope=0.2) 
    x = F.relu(self.fc2(x), 0.2)
    out = self.tanh(self.fc3(x))
    return out

Generator_model = Generator(latent_size, hidden_size,image_size).to(device);

# %%
print(Generator_model)
print(Discriminator_model)
# Out:
# Generator(
#   (fc1): Linear(in_features=64, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=784, bias=True)
#   (tanh): Tanh()
# )
# Discriminator(
#   (fc1): Linear(in_features=784, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=1, bias=True)
#   (sig): Sigmoid()
# )

# %%
y = Generator_model(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
#For discriminator training using binary cross entropy loss
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(Discriminator_model.parameters(), lr=0.0002)
g_optimizer = torch.optim.Adam(Generator_model.parameters(), lr=0.0002)

# %%
# utility function

def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

# %%
#Train discriminator
def train_discriminator(images):
    
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)
        
    # calculate loss on real image
    outputs = Discriminator_model(images)
    d_real_image_loss = criterion(outputs, real_labels)
    real_score = outputs

    # generate fake images and calculate loss on fake image
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = Generator_model(z)
    outputs = Discriminator_model(fake_images)
    d_fake_image_loss = criterion(outputs, fake_labels)
    fake_score = outputs

    #loss addition
    d_total_loss = d_real_image_loss + d_fake_image_loss
    # set zero grad
    reset_grad()
    # backword
    d_total_loss.backward()
    # forword
    d_optimizer.step()
    
    return d_total_loss, real_score, fake_score

# %%
#Generator training

def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = Generator_model(z)
    labels = torch.ones(batch_size, 1).to(device)
    # Passing fake images and calculating loss on real label
    g_loss = criterion(Discriminator_model(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %%
import os
# Saving data to visiualization

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Saving real images first
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break
   
Image(os.path.join(sample_dir, 'real_images.png'))

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)
# saving fake images too
def save_fake_images(index):
    fake_images = Generator_model(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)
    
# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %%
# %%time

#Training the model now and saving fake images in the folder
num_epochs = 50
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)
        
        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()
        
        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(), 
                          real_score.mean().item(), fake_score.mean().item()))
        
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/50], Step [200/600], d_loss: 0.0640, g_loss: 4.1680, D(x): 0.98, D(G(z)): 0.04
# Epoch [0/50], Step [400/600], d_loss: 0.2210, g_loss: 4.4072, D(x): 0.95, D(G(z)): 0.10
# Epoch [0/50], Step [600/600], d_loss: 0.0489, g_loss: 5.0928, D(x): 0.98, D(G(z)): 0.03
# Saving fake_images-0001.png
# Epoch [1/50], Step [200/600], d_loss: 0.1044, g_loss: 3.8336, D(x): 0.97, D(G(z)): 0.07
# Epoch [1/50], Step [400/600], d_loss: 0.0397, g_loss: 3.8679, D(x): 0.99, D(G(z)): 0.03
# Epoch [1/50], Step [600/600], d_loss: 0.0304, g_loss: 4.3869, D(x): 0.99, D(G(z)): 0.02
# Saving fake_images-0002.png
# Epoch [2/50], Step [200/600], d_loss: 0.0154, g_loss: 5.0514, D(x): 1.00, D(G(z)): 0.01
# Epoch [2/50], Step [400/600], d_loss: 0.0290, g_loss: 6.3961, D(x): 0.99, D(G(z)): 0.01
# Epoch [2/50], Step [600/600], d_loss: 0.0382, g_loss: 6.3870, D(x): 1.00, D(G(z)): 0.03
# Saving fake_images-0003.png
# Epoch [3/50], Step [200/600], d_loss: 0.0710, g_loss: 5.3176, D(x): 0.96, D(G(z)): 0.01
# Epoch [3/50], Step [400/600], d_loss: 0.1182, g_loss: 4.7273, D(x): 0.96, D(G(z)): 0.02
# Epoch [3/50], Step [600/600], d_loss: 0.0725, g_loss: 4.2575, D(x): 0.98, D(G(z)): 0.05
# Saving fake_images-0004.png
# Epoch [4/50], Step [200/600], d_loss: 0.0168, g_loss: 7.0291, D(x): 0.99, D(G(z)): 0.01
# Epoch [4/50], Step [400/600], d_loss: 0.2556, g_loss: 4.5999, D(x): 0.98, D(G(z)): 0.17
# Epoch [4/50], Step [600/600], d_loss: 0.0842, g_loss: 5.0684, D(x): 0.99, D(G(z)): 0.03
# Saving fake_images-0005.png
# Epoch [5/50], Step [200/600], d_loss: 0.2091, g_loss: 4.2577, D(x): 0.92, D(G(z)): 0.06
# Epoch [5/50], Step [400/600], d_loss: 0.2819, g_loss: 4.0887, D(x): 0.94, D(G(z)): 0.05
# Epoch [5/50], Step [600/600], d_loss: 0.2619, g_loss: 4.5515, D(x): 0.92, D(G(z)): 0.05
# Saving fake_images-0006.png
# Epoch [6/50], Step [200/600], d_loss: 0.0486, g_loss: 5.4286, D(x): 0.98, D(G(z)): 0.02
# Epoch [6/50], Step [400/600], d_loss: 0.1028, g_loss: 3.3787, D(x): 0.98, D(G(z)): 0.05
# Epoch [6/50], Step [600/600], d_loss: 0.1664, g_loss: 4.7764, D(x): 0.94, D(G(z)): 0.04
# Saving fake_images-0007.png
# Epoch [7/50], Step [200/600], d_loss: 0.1116, g_loss: 4.7829, D(x): 0.96, D(G(z)): 0.02
# Epoch [7/50], Step [400/600], d_loss: 0.1181, g_loss: 5.0921, D(x): 0.97, D(G(z)): 0.06
# Epoch [7/50], Step [600/600], d_loss: 0.3257, g_loss: 5.6127, D(x): 0.92, D(G(z)): 0.05
# Saving fake_images-0008.png
# Epoch [8/50], Step [200/600], d_loss: 0.0807, g_loss: 5.1731, D(x): 0.96, D(G(z)): 0.03
# Epoch [8/50], Step [400/600], d_loss: 0.3133, g_loss: 4.2131, D(x): 0.92, D(G(z)): 0.07
# Epoch [8/50], Step [600/600], d_loss: 0.3151, g_loss: 3.9016, D(x): 0.93, D(G(z)): 0.10
# Saving fake_images-0009.png
# Epoch [9/50], Step [200/600], d_loss: 0.3589, g_loss: 5.0941, D(x): 0.90, D(G(z)): 0.09
# Epoch [9/50], Step [400/600], d_loss: 0.1579, g_loss: 5.0467, D(x): 0.95, D(G(z)): 0.04
# Epoch [9/50], Step [600/600], d_loss: 0.2560, g_loss: 4.8330, D(x): 0.89, D(G(z)): 0.06
# Saving fake_images-0010.png
# Epoch [10/50], Step [200/600], d_loss: 0.3844, g_loss: 4.1550, D(x): 0.91, D(G(z)): 0.10
# Epoch [10/50], Step [400/600], d_loss: 0.5782, g_loss: 4.4683, D(x): 0.88, D(G(z)): 0.07
# Epoch [10/50], Step [600/600], d_loss: 0.2339, g_loss: 4.9898, D(x): 0.92, D(G(z)): 0.02
# Saving fake_images-0011.png
# Epoch [11/50], Step [200/600], d_loss: 0.2582, g_loss: 4.1467, D(x): 0.92, D(G(z)): 0.08
# Epoch [11/50], Step [400/600], d_loss: 0.2902, g_loss: 2.7986, D(x): 0.95, D(G(z)): 0.17
# Epoch [11/50], Step [600/600], d_loss: 0.2168, g_loss: 3.9492, D(x): 0.95, D(G(z)): 0.11
# Saving fake_images-0012.png
# Epoch [12/50], Step [200/600], d_loss: 0.4112, g_loss: 3.2932, D(x): 0.94, D(G(z)): 0.16
# Epoch [12/50], Step [400/600], d_loss: 0.3538, g_loss: 4.1097, D(x): 0.85, D(G(z)): 0.05
# Epoch [12/50], Step [600/600], d_loss: 0.2053, g_loss: 2.8991, D(x): 0.94, D(G(z)): 0.10
# Saving fake_images-0013.png
# Epoch [13/50], Step [200/600], d_loss: 0.5116, g_loss: 1.8231, D(x): 0.92, D(G(z)): 0.22
# Epoch [13/50], Step [400/600], d_loss: 0.1629, g_loss: 3.7890, D(x): 0.95, D(G(z)): 0.08
# Epoch [13/50], Step [600/600], d_loss: 0.5851, g_loss: 4.0647, D(x): 0.86, D(G(z)): 0.15
# Saving fake_images-0014.png
# Epoch [14/50], Step [200/600], d_loss: 0.5266, g_loss: 3.7968, D(x): 0.84, D(G(z)): 0.09
# Epoch [14/50], Step [400/600], d_loss: 0.5061, g_loss: 3.2706, D(x): 0.87, D(G(z)): 0.17
# Epoch [14/50], Step [600/600], d_loss: 0.3314, g_loss: 3.2943, D(x): 0.90, D(G(z)): 0.11
# Saving fake_images-0015.png
# Epoch [15/50], Step [200/600], d_loss: 0.2745, g_loss: 4.5383, D(x): 0.89, D(G(z)): 0.05
# Epoch [15/50], Step [400/600], d_loss: 0.5049, g_loss: 3.8411, D(x): 0.85, D(G(z)): 0.10
# Epoch [15/50], Step [600/600], d_loss: 0.4899, g_loss: 3.4116, D(x): 0.84, D(G(z)): 0.05
# Saving fake_images-0016.png
# Epoch [16/50], Step [200/600], d_loss: 0.4501, g_loss: 3.9476, D(x): 0.88, D(G(z)): 0.13
# Epoch [16/50], Step [400/600], d_loss: 0.6134, g_loss: 4.7411, D(x): 0.79, D(G(z)): 0.03
# Epoch [16/50], Step [600/600], d_loss: 0.2104, g_loss: 4.9968, D(x): 0.93, D(G(z)): 0.07
# Saving fake_images-0017.png
# Epoch [17/50], Step [200/600], d_loss: 0.3267, g_loss: 4.2940, D(x): 0.92, D(G(z)): 0.09
# Epoch [17/50], Step [400/600], d_loss: 0.5181, g_loss: 4.6098, D(x): 0.82, D(G(z)): 0.04
# Epoch [17/50], Step [600/600], d_loss: 0.1810, g_loss: 4.8089, D(x): 0.92, D(G(z)): 0.04
# Saving fake_images-0018.png
# Epoch [18/50], Step [200/600], d_loss: 0.3702, g_loss: 2.8239, D(x): 0.92, D(G(z)): 0.16
# Epoch [18/50], Step [400/600], d_loss: 0.6697, g_loss: 3.1376, D(x): 0.87, D(G(z)): 0.25
# Epoch [18/50], Step [600/600], d_loss: 0.7358, g_loss: 2.9426, D(x): 0.83, D(G(z)): 0.16
# Saving fake_images-0019.png
# Epoch [19/50], Step [200/600], d_loss: 0.2992, g_loss: 3.6058, D(x): 0.91, D(G(z)): 0.10
# Epoch [19/50], Step [400/600], d_loss: 0.3665, g_loss: 3.5683, D(x): 0.87, D(G(z)): 0.07
# Epoch [19/50], Step [600/600], d_loss: 0.3445, g_loss: 3.5813, D(x): 0.92, D(G(z)): 0.16
# Saving fake_images-0020.png
# Epoch [20/50], Step [200/600], d_loss: 0.6097, g_loss: 3.1078, D(x): 0.79, D(G(z)): 0.08
# Epoch [20/50], Step [400/600], d_loss: 0.2972, g_loss: 3.8149, D(x): 0.92, D(G(z)): 0.12
# Epoch [20/50], Step [600/600], d_loss: 0.4544, g_loss: 2.7556, D(x): 0.93, D(G(z)): 0.18
# Saving fake_images-0021.png
# Epoch [21/50], Step [200/600], d_loss: 0.4308, g_loss: 3.8613, D(x): 0.87, D(G(z)): 0.13
# Epoch [21/50], Step [400/600], d_loss: 0.4890, g_loss: 3.6645, D(x): 0.83, D(G(z)): 0.13
# Epoch [21/50], Step [600/600], d_loss: 0.5597, g_loss: 3.6083, D(x): 0.87, D(G(z)): 0.15
# Saving fake_images-0022.png
# Epoch [22/50], Step [200/600], d_loss: 0.2862, g_loss: 3.5907, D(x): 0.91, D(G(z)): 0.11
# Epoch [22/50], Step [400/600], d_loss: 0.3967, g_loss: 2.8418, D(x): 0.95, D(G(z)): 0.21
# Epoch [22/50], Step [600/600], d_loss: 0.6403, g_loss: 2.9544, D(x): 0.86, D(G(z)): 0.24
# Saving fake_images-0023.png
# Epoch [23/50], Step [200/600], d_loss: 0.4387, g_loss: 3.0111, D(x): 0.85, D(G(z)): 0.12
# Epoch [23/50], Step [400/600], d_loss: 0.2926, g_loss: 2.8812, D(x): 0.89, D(G(z)): 0.09
# Epoch [23/50], Step [600/600], d_loss: 0.5554, g_loss: 2.3004, D(x): 0.87, D(G(z)): 0.17
# Saving fake_images-0024.png
# Epoch [24/50], Step [200/600], d_loss: 0.5860, g_loss: 2.2238, D(x): 0.88, D(G(z)): 0.22
# Epoch [24/50], Step [400/600], d_loss: 0.5316, g_loss: 3.0302, D(x): 0.80, D(G(z)): 0.11
# Epoch [24/50], Step [600/600], d_loss: 0.5044, g_loss: 3.1208, D(x): 0.86, D(G(z)): 0.13
# Saving fake_images-0025.png
# Epoch [25/50], Step [200/600], d_loss: 0.4226, g_loss: 3.5315, D(x): 0.87, D(G(z)): 0.09
# Epoch [25/50], Step [400/600], d_loss: 0.4334, g_loss: 3.5861, D(x): 0.86, D(G(z)): 0.09
# Epoch [25/50], Step [600/600], d_loss: 0.3539, g_loss: 3.0651, D(x): 0.90, D(G(z)): 0.14
# Saving fake_images-0026.png
# Epoch [26/50], Step [200/600], d_loss: 0.2294, g_loss: 3.4591, D(x): 0.90, D(G(z)): 0.06
# Epoch [26/50], Step [400/600], d_loss: 0.5917, g_loss: 4.0437, D(x): 0.81, D(G(z)): 0.10
# Epoch [26/50], Step [600/600], d_loss: 0.3521, g_loss: 3.0253, D(x): 0.87, D(G(z)): 0.11
# Saving fake_images-0027.png
# Epoch [27/50], Step [200/600], d_loss: 0.5883, g_loss: 2.9654, D(x): 0.80, D(G(z)): 0.13
# Epoch [27/50], Step [400/600], d_loss: 0.4385, g_loss: 3.1886, D(x): 0.88, D(G(z)): 0.16
# Epoch [27/50], Step [600/600], d_loss: 0.3677, g_loss: 3.5723, D(x): 0.92, D(G(z)): 0.17
# Saving fake_images-0028.png
# Epoch [28/50], Step [200/600], d_loss: 0.5947, g_loss: 2.6552, D(x): 0.82, D(G(z)): 0.17
# Epoch [28/50], Step [400/600], d_loss: 0.5445, g_loss: 3.6261, D(x): 0.78, D(G(z)): 0.08
# Epoch [28/50], Step [600/600], d_loss: 0.3478, g_loss: 3.2890, D(x): 0.93, D(G(z)): 0.16
# Saving fake_images-0029.png
# Epoch [29/50], Step [200/600], d_loss: 0.3551, g_loss: 3.1940, D(x): 0.85, D(G(z)): 0.09
# Epoch [29/50], Step [400/600], d_loss: 0.5362, g_loss: 2.9787, D(x): 0.85, D(G(z)): 0.17
# Epoch [29/50], Step [600/600], d_loss: 0.5395, g_loss: 2.4053, D(x): 0.88, D(G(z)): 0.21
# Saving fake_images-0030.png
# Epoch [30/50], Step [200/600], d_loss: 0.4237, g_loss: 2.5382, D(x): 0.92, D(G(z)): 0.20
# Epoch [30/50], Step [400/600], d_loss: 0.4117, g_loss: 3.6354, D(x): 0.88, D(G(z)): 0.12
# Epoch [30/50], Step [600/600], d_loss: 0.5702, g_loss: 2.6741, D(x): 0.88, D(G(z)): 0.25
# Saving fake_images-0031.png
# Epoch [31/50], Step [200/600], d_loss: 0.5308, g_loss: 3.3148, D(x): 0.83, D(G(z)): 0.13
# Epoch [31/50], Step [400/600], d_loss: 0.3923, g_loss: 3.9194, D(x): 0.88, D(G(z)): 0.12
# Epoch [31/50], Step [600/600], d_loss: 0.5243, g_loss: 3.0806, D(x): 0.80, D(G(z)): 0.13
# Saving fake_images-0032.png
# Epoch [32/50], Step [200/600], d_loss: 0.5373, g_loss: 2.7886, D(x): 0.92, D(G(z)): 0.26
# Epoch [32/50], Step [400/600], d_loss: 0.5194, g_loss: 3.0717, D(x): 0.83, D(G(z)): 0.11
# Epoch [32/50], Step [600/600], d_loss: 0.6462, g_loss: 2.9807, D(x): 0.79, D(G(z)): 0.12
# Saving fake_images-0033.png
# Epoch [33/50], Step [200/600], d_loss: 0.3877, g_loss: 2.8116, D(x): 0.85, D(G(z)): 0.09
# Epoch [33/50], Step [400/600], d_loss: 0.4619, g_loss: 2.8781, D(x): 0.87, D(G(z)): 0.13
# Epoch [33/50], Step [600/600], d_loss: 0.6589, g_loss: 3.2175, D(x): 0.79, D(G(z)): 0.10
# Saving fake_images-0034.png
# Epoch [34/50], Step [200/600], d_loss: 0.6723, g_loss: 3.0062, D(x): 0.85, D(G(z)): 0.19
# Epoch [34/50], Step [400/600], d_loss: 0.3917, g_loss: 4.1243, D(x): 0.87, D(G(z)): 0.12
# Epoch [34/50], Step [600/600], d_loss: 0.4497, g_loss: 3.4554, D(x): 0.80, D(G(z)): 0.07
# Saving fake_images-0035.png
# Epoch [35/50], Step [200/600], d_loss: 0.5336, g_loss: 3.7734, D(x): 0.84, D(G(z)): 0.15
# Epoch [35/50], Step [400/600], d_loss: 0.5430, g_loss: 2.4604, D(x): 0.85, D(G(z)): 0.17
# Epoch [35/50], Step [600/600], d_loss: 0.5672, g_loss: 2.7981, D(x): 0.88, D(G(z)): 0.20
# Saving fake_images-0036.png
# Epoch [36/50], Step [200/600], d_loss: 0.4986, g_loss: 2.8321, D(x): 0.86, D(G(z)): 0.17
# Epoch [36/50], Step [400/600], d_loss: 0.5985, g_loss: 2.7762, D(x): 0.77, D(G(z)): 0.11
# Epoch [36/50], Step [600/600], d_loss: 0.4787, g_loss: 2.4934, D(x): 0.91, D(G(z)): 0.20
# Saving fake_images-0037.png
# Epoch [37/50], Step [200/600], d_loss: 0.6197, g_loss: 2.7467, D(x): 0.81, D(G(z)): 0.19
# Epoch [37/50], Step [400/600], d_loss: 0.4722, g_loss: 3.2392, D(x): 0.83, D(G(z)): 0.14
# Epoch [37/50], Step [600/600], d_loss: 0.6265, g_loss: 3.0529, D(x): 0.77, D(G(z)): 0.14
# Saving fake_images-0038.png
# Epoch [38/50], Step [200/600], d_loss: 0.6672, g_loss: 3.0428, D(x): 0.79, D(G(z)): 0.19
# Epoch [38/50], Step [400/600], d_loss: 0.8625, g_loss: 2.4525, D(x): 0.75, D(G(z)): 0.22
# Epoch [38/50], Step [600/600], d_loss: 0.4726, g_loss: 3.5423, D(x): 0.85, D(G(z)): 0.11
# Saving fake_images-0039.png
# Epoch [39/50], Step [200/600], d_loss: 0.5489, g_loss: 2.7809, D(x): 0.80, D(G(z)): 0.13
# Epoch [39/50], Step [400/600], d_loss: 0.6166, g_loss: 3.2478, D(x): 0.77, D(G(z)): 0.14
# Epoch [39/50], Step [600/600], d_loss: 0.6952, g_loss: 2.5279, D(x): 0.78, D(G(z)): 0.20
# Saving fake_images-0040.png
# Epoch [40/50], Step [200/600], d_loss: 0.5099, g_loss: 2.7911, D(x): 0.83, D(G(z)): 0.16
# Epoch [40/50], Step [400/600], d_loss: 0.5834, g_loss: 2.3537, D(x): 0.84, D(G(z)): 0.22
# Epoch [40/50], Step [600/600], d_loss: 0.6571, g_loss: 2.8380, D(x): 0.79, D(G(z)): 0.14
# Saving fake_images-0041.png
# Epoch [41/50], Step [200/600], d_loss: 0.6261, g_loss: 2.7527, D(x): 0.81, D(G(z)): 0.18
# Epoch [41/50], Step [400/600], d_loss: 0.6753, g_loss: 2.8368, D(x): 0.76, D(G(z)): 0.15
# Epoch [41/50], Step [600/600], d_loss: 0.9772, g_loss: 2.6253, D(x): 0.71, D(G(z)): 0.23
# Saving fake_images-0042.png
# Epoch [42/50], Step [200/600], d_loss: 0.8510, g_loss: 2.0088, D(x): 0.78, D(G(z)): 0.27
# Epoch [42/50], Step [400/600], d_loss: 0.5356, g_loss: 2.1560, D(x): 0.79, D(G(z)): 0.14
# Epoch [42/50], Step [600/600], d_loss: 0.6693, g_loss: 2.0932, D(x): 0.82, D(G(z)): 0.24
# Saving fake_images-0043.png
# Epoch [43/50], Step [200/600], d_loss: 0.5534, g_loss: 3.6664, D(x): 0.88, D(G(z)): 0.22
# Epoch [43/50], Step [400/600], d_loss: 0.6525, g_loss: 2.3573, D(x): 0.81, D(G(z)): 0.22
# Epoch [43/50], Step [600/600], d_loss: 0.5757, g_loss: 3.0144, D(x): 0.77, D(G(z)): 0.15
# Saving fake_images-0044.png
# Epoch [44/50], Step [200/600], d_loss: 0.5798, g_loss: 2.4569, D(x): 0.87, D(G(z)): 0.25
# Epoch [44/50], Step [400/600], d_loss: 0.8133, g_loss: 2.5294, D(x): 0.77, D(G(z)): 0.22
# Epoch [44/50], Step [600/600], d_loss: 0.6135, g_loss: 1.7887, D(x): 0.79, D(G(z)): 0.17
# Saving fake_images-0045.png
# Epoch [45/50], Step [200/600], d_loss: 0.8437, g_loss: 2.9397, D(x): 0.75, D(G(z)): 0.21
# Epoch [45/50], Step [400/600], d_loss: 0.7101, g_loss: 2.1047, D(x): 0.79, D(G(z)): 0.24
# Epoch [45/50], Step [600/600], d_loss: 0.9461, g_loss: 2.4518, D(x): 0.67, D(G(z)): 0.16
# Saving fake_images-0046.png
# Epoch [46/50], Step [200/600], d_loss: 0.6142, g_loss: 2.2051, D(x): 0.80, D(G(z)): 0.22
# Epoch [46/50], Step [400/600], d_loss: 0.6352, g_loss: 2.3932, D(x): 0.80, D(G(z)): 0.22
# Epoch [46/50], Step [600/600], d_loss: 0.6467, g_loss: 2.1711, D(x): 0.84, D(G(z)): 0.28
# Saving fake_images-0047.png
# Epoch [47/50], Step [200/600], d_loss: 0.7341, g_loss: 2.9839, D(x): 0.75, D(G(z)): 0.14
# Epoch [47/50], Step [400/600], d_loss: 0.6363, g_loss: 2.8387, D(x): 0.83, D(G(z)): 0.24
# Epoch [47/50], Step [600/600], d_loss: 0.7754, g_loss: 2.4971, D(x): 0.83, D(G(z)): 0.30
# Saving fake_images-0048.png
# Epoch [48/50], Step [200/600], d_loss: 0.6058, g_loss: 2.0029, D(x): 0.84, D(G(z)): 0.23
# Epoch [48/50], Step [400/600], d_loss: 0.5813, g_loss: 2.5330, D(x): 0.82, D(G(z)): 0.19
# Epoch [48/50], Step [600/600], d_loss: 0.5949, g_loss: 2.7762, D(x): 0.81, D(G(z)): 0.18
# Saving fake_images-0049.png
# Epoch [49/50], Step [200/600], d_loss: 0.5583, g_loss: 2.8798, D(x): 0.78, D(G(z)): 0.13
# Epoch [49/50], Step [400/600], d_loss: 0.8449, g_loss: 2.0251, D(x): 0.74, D(G(z)): 0.20
# Epoch [49/50], Step [600/600], d_loss: 0.6830, g_loss: 2.6171, D(x): 0.78, D(G(z)): 0.20
# Saving fake_images-0050.png
# CPU times: user 21min 7s, sys: 32.8 s, total: 21min 40s
# Wall time: 21min 38s

# %%
# Save the model checkpoints 
torch.save(Generator_model.state_dict(), 'G.ckpt')
torch.save(Discriminator_model.state_dict(), 'D.ckpt')

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %%
import glob
from PIL import Image

# filepaths
fp_in = "/content/samples/fake_images-*.png"
fp_out = "/content/samples/fake_image.gif"

# https://pillow.readthedocs.io/en/stable/handbook/image-file-formats.html#gif
imgs = (Image.open(f) for f in sorted(glob.glob(fp_in)))
img = next(imgs)  # extract first image from iterator
img.save(fp=fp_out, format='GIF', append_images=imgs,
         save_all=True, duration=200, loop=0)
