# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import FashionMNIST
from torchvision.utils import make_grid
import torch.nn.functional as F

# %%
#Load Fashion MNIST data set

mnist = FashionMNIST(root='data', 
              train=True, 
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))

to_pil_image = torchvision.transforms.ToPILImage()

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
from torch.utils.data import DataLoader

#Data loader
batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %%
#Discriminator networ parameter
image_size = 784
hidden_size = 256

# %%
import torch.nn as nn

# #Discriminator
class Discriminator(nn.Module):
  def __init__(self, image_size, hidden_size):
    super(Discriminator, self).__init__()

    self.fc1 = nn.Linear(image_size, hidden_size)
    self.fc2 = nn.Linear(hidden_size, hidden_size)
    self.fc3 = nn.Linear(hidden_size, 1)
    self.sig = nn.Sigmoid()

  def forward(self, x):
     x = F.leaky_relu(self.fc1(x), 0.2)  
     x = F.leaky_relu(self.fc2(x), 0.2)  
     out = self.sig(self.fc3(x))
     return out


Discriminator_model = Discriminator(image_size, hidden_size).to(device);

# %%
#Generator network parameter
latent_size = 64

class Generator(nn.Module):
  def __init__(self, latent_size, hidden_size, image_size):
    super(Generator, self).__init__()
    
    self.fc1 = nn.Linear(latent_size, hidden_size)
    self.fc2 = nn.Linear(hidden_size, hidden_size)
    self.fc3 = nn.Linear(hidden_size, image_size)
    self.tanh = nn.Tanh()
    
  def forward(self, x):
    # 4
    x = F.relu(self.fc1(x), 0.2) # (input, negative_slope=0.2) 
    x = F.relu(self.fc2(x), 0.2)
    out = self.tanh(self.fc3(x))
    return out

Generator_model = Generator(latent_size, hidden_size,image_size).to(device);

# %%
print(Generator_model)
print(Discriminator_model)
# Out:
# Generator(
#   (fc1): Linear(in_features=64, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=784, bias=True)
#   (tanh): Tanh()
# )
# Discriminator(
#   (fc1): Linear(in_features=784, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=1, bias=True)
#   (sig): Sigmoid()
# )

# %%
#For discriminator training using binary cross entropy loss
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(Discriminator_model.parameters(), lr=0.0002)
g_optimizer = torch.optim.Adam(Generator_model.parameters(), lr=0.0002)

# %%
# utility function
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

# %%
#Train discriminator
def train_discriminator(images):
    
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)
        
    # calculate loss on real image
    outputs = Discriminator_model(images)
    d_real_image_loss = criterion(outputs, real_labels)
    real_score = outputs

    # generate fake images and calculate loss on fake image
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = Generator_model(z)
    outputs = Discriminator_model(fake_images)
    d_fake_image_loss = criterion(outputs, fake_labels)
    fake_score = outputs

    #loss addition
    d_total_loss = d_real_image_loss + d_fake_image_loss
    # set zero grad
    reset_grad()
    # backword
    d_total_loss.backward()
    # forword
    d_optimizer.step()
    
    return d_total_loss, real_score, fake_score

# %%
#Generator training

def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = Generator_model(z)
    labels = torch.ones(batch_size, 1).to(device)
    # Passing fake images and calculating loss on real label
    g_loss = criterion(Discriminator_model(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %%
import os
# Saving data to visiualization

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Saving real images first
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)
# saving fake images too
def save_fake_images(index):
    fake_images = Generator_model(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)
    
# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %%
# %%time

#Training the model now and saving fake images in the folder
num_epochs = 100
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)
        
        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()
        
        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(), 
                          real_score.mean().item(), fake_score.mean().item()))
        
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/100], Step [200/600], d_loss: 0.0770, g_loss: 4.0172, D(x): 0.98, D(G(z)): 0.06
# Epoch [0/100], Step [400/600], d_loss: 0.2278, g_loss: 5.4894, D(x): 0.94, D(G(z)): 0.08
# Epoch [0/100], Step [600/600], d_loss: 0.0614, g_loss: 4.7806, D(x): 0.97, D(G(z)): 0.02
# Saving fake_images-0001.png
# Epoch [1/100], Step [200/600], d_loss: 0.0492, g_loss: 5.1527, D(x): 0.98, D(G(z)): 0.02
# Epoch [1/100], Step [400/600], d_loss: 0.0416, g_loss: 4.6819, D(x): 0.98, D(G(z)): 0.02
# Epoch [1/100], Step [600/600], d_loss: 0.0629, g_loss: 6.0632, D(x): 0.98, D(G(z)): 0.01
# Saving fake_images-0002.png
# Epoch [2/100], Step [200/600], d_loss: 0.0474, g_loss: 6.3080, D(x): 0.98, D(G(z)): 0.01
# Epoch [2/100], Step [400/600], d_loss: 0.0274, g_loss: 8.7651, D(x): 1.00, D(G(z)): 0.02
# Epoch [2/100], Step [600/600], d_loss: 0.0164, g_loss: 7.3548, D(x): 1.00, D(G(z)): 0.01
# Saving fake_images-0003.png
# Epoch [3/100], Step [200/600], d_loss: 0.0258, g_loss: 4.9584, D(x): 0.99, D(G(z)): 0.02
# Epoch [3/100], Step [400/600], d_loss: 0.0607, g_loss: 6.3395, D(x): 0.98, D(G(z)): 0.03
# Epoch [3/100], Step [600/600], d_loss: 0.0434, g_loss: 5.7937, D(x): 0.99, D(G(z)): 0.01
# Saving fake_images-0004.png
# Epoch [4/100], Step [200/600], d_loss: 0.1509, g_loss: 5.1555, D(x): 0.93, D(G(z)): 0.02
# Epoch [4/100], Step [400/600], d_loss: 0.0717, g_loss: 7.7710, D(x): 0.98, D(G(z)): 0.02
# Epoch [4/100], Step [600/600], d_loss: 0.0345, g_loss: 6.8677, D(x): 0.99, D(G(z)): 0.02
# Saving fake_images-0005.png
# Epoch [5/100], Step [200/600], d_loss: 0.1129, g_loss: 5.2379, D(x): 0.97, D(G(z)): 0.02
# Epoch [5/100], Step [400/600], d_loss: 0.0940, g_loss: 6.1640, D(x): 0.97, D(G(z)): 0.01
# Epoch [5/100], Step [600/600], d_loss: 0.0254, g_loss: 7.1391, D(x): 0.99, D(G(z)): 0.02
# Saving fake_images-0006.png
# Epoch [6/100], Step [200/600], d_loss: 0.0841, g_loss: 4.6497, D(x): 0.97, D(G(z)): 0.04
# Epoch [6/100], Step [400/600], d_loss: 0.0609, g_loss: 5.6167, D(x): 1.00, D(G(z)): 0.05
# Epoch [6/100], Step [600/600], d_loss: 0.0763, g_loss: 7.1104, D(x): 0.98, D(G(z)): 0.02
# Saving fake_images-0007.png
# Epoch [7/100], Step [200/600], d_loss: 0.1524, g_loss: 8.1483, D(x): 0.96, D(G(z)): 0.05
# Epoch [7/100], Step [400/600], d_loss: 0.2252, g_loss: 5.4242, D(x): 0.95, D(G(z)): 0.10
# Epoch [7/100], Step [600/600], d_loss: 0.3327, g_loss: 5.2732, D(x): 0.98, D(G(z)): 0.19
# Saving fake_images-0008.png
# Epoch [8/100], Step [200/600], d_loss: 0.1798, g_loss: 5.0804, D(x): 0.95, D(G(z)): 0.04
# Epoch [8/100], Step [400/600], d_loss: 0.1337, g_loss: 4.5773, D(x): 0.96, D(G(z)): 0.05
# Epoch [8/100], Step [600/600], d_loss: 0.1394, g_loss: 5.4416, D(x): 0.96, D(G(z)): 0.07
# Saving fake_images-0009.png
# Epoch [9/100], Step [200/600], d_loss: 0.2656, g_loss: 4.4829, D(x): 0.91, D(G(z)): 0.02
# Epoch [9/100], Step [400/600], d_loss: 0.2219, g_loss: 3.2573, D(x): 0.92, D(G(z)): 0.06
# Epoch [9/100], Step [600/600], d_loss: 0.2310, g_loss: 4.7167, D(x): 0.93, D(G(z)): 0.05
# Saving fake_images-0010.png
# Epoch [10/100], Step [200/600], d_loss: 0.1259, g_loss: 5.9639, D(x): 0.95, D(G(z)): 0.02
# Epoch [10/100], Step [400/600], d_loss: 0.2111, g_loss: 4.5143, D(x): 0.96, D(G(z)): 0.05
# Epoch [10/100], Step [600/600], d_loss: 0.2417, g_loss: 4.6459, D(x): 0.91, D(G(z)): 0.04
# Saving fake_images-0011.png
# Epoch [11/100], Step [200/600], d_loss: 0.4588, g_loss: 3.7052, D(x): 0.90, D(G(z)): 0.10
# Epoch [11/100], Step [400/600], d_loss: 0.4285, g_loss: 6.0350, D(x): 0.89, D(G(z)): 0.04
# Epoch [11/100], Step [600/600], d_loss: 0.2807, g_loss: 5.3989, D(x): 0.89, D(G(z)): 0.03
# Saving fake_images-0012.png
# Epoch [12/100], Step [200/600], d_loss: 0.2376, g_loss: 4.1980, D(x): 0.95, D(G(z)): 0.12
# Epoch [12/100], Step [400/600], d_loss: 0.4076, g_loss: 4.0715, D(x): 0.89, D(G(z)): 0.08
# Epoch [12/100], Step [600/600], d_loss: 0.4202, g_loss: 4.5542, D(x): 0.86, D(G(z)): 0.07
# Saving fake_images-0013.png
# Epoch [13/100], Step [200/600], d_loss: 0.2322, g_loss: 4.7822, D(x): 0.93, D(G(z)): 0.07
# Epoch [13/100], Step [400/600], d_loss: 0.1756, g_loss: 4.3856, D(x): 0.96, D(G(z)): 0.10
# Epoch [13/100], Step [600/600], d_loss: 0.1693, g_loss: 3.9736, D(x): 0.95, D(G(z)): 0.09
# Saving fake_images-0014.png
# Epoch [14/100], Step [200/600], d_loss: 0.4147, g_loss: 3.2609, D(x): 0.93, D(G(z)): 0.20
# Epoch [14/100], Step [400/600], d_loss: 0.2159, g_loss: 3.6022, D(x): 0.93, D(G(z)): 0.08
# Epoch [14/100], Step [600/600], d_loss: 0.2168, g_loss: 4.7497, D(x): 0.92, D(G(z)): 0.07
# Saving fake_images-0015.png
# Epoch [15/100], Step [200/600], d_loss: 0.2780, g_loss: 3.6246, D(x): 0.94, D(G(z)): 0.11
# Epoch [15/100], Step [400/600], d_loss: 0.4458, g_loss: 3.4211, D(x): 0.89, D(G(z)): 0.13
# Epoch [15/100], Step [600/600], d_loss: 0.3422, g_loss: 3.8004, D(x): 0.87, D(G(z)): 0.06
# Saving fake_images-0016.png
# Epoch [16/100], Step [200/600], d_loss: 0.2260, g_loss: 3.5320, D(x): 0.90, D(G(z)): 0.07
# Epoch [16/100], Step [400/600], d_loss: 0.2506, g_loss: 3.9620, D(x): 0.92, D(G(z)): 0.08
# Epoch [16/100], Step [600/600], d_loss: 0.2846, g_loss: 3.4962, D(x): 0.92, D(G(z)): 0.13
# Saving fake_images-0017.png
# Epoch [17/100], Step [200/600], d_loss: 0.5509, g_loss: 2.7539, D(x): 0.84, D(G(z)): 0.13
# Epoch [17/100], Step [400/600], d_loss: 0.7007, g_loss: 4.3381, D(x): 0.77, D(G(z)): 0.05
# Epoch [17/100], Step [600/600], d_loss: 0.3297, g_loss: 3.8133, D(x): 0.89, D(G(z)): 0.07
# Saving fake_images-0018.png
# Epoch [18/100], Step [200/600], d_loss: 0.4648, g_loss: 3.0955, D(x): 0.90, D(G(z)): 0.15
# Epoch [18/100], Step [400/600], d_loss: 0.3750, g_loss: 3.4851, D(x): 0.90, D(G(z)): 0.15
# Epoch [18/100], Step [600/600], d_loss: 0.2652, g_loss: 3.3944, D(x): 0.92, D(G(z)): 0.12
# Saving fake_images-0019.png
# Epoch [19/100], Step [200/600], d_loss: 0.5408, g_loss: 2.9710, D(x): 0.94, D(G(z)): 0.25
# Epoch [19/100], Step [400/600], d_loss: 0.4801, g_loss: 4.3668, D(x): 0.82, D(G(z)): 0.07
# Epoch [19/100], Step [600/600], d_loss: 0.2920, g_loss: 4.1364, D(x): 0.90, D(G(z)): 0.09
# Saving fake_images-0020.png
# Epoch [20/100], Step [200/600], d_loss: 0.3502, g_loss: 3.3431, D(x): 0.93, D(G(z)): 0.12
# Epoch [20/100], Step [400/600], d_loss: 0.4200, g_loss: 2.5661, D(x): 0.88, D(G(z)): 0.14
# Epoch [20/100], Step [600/600], d_loss: 0.3560, g_loss: 3.0247, D(x): 0.91, D(G(z)): 0.16
# Saving fake_images-0021.png
# Epoch [21/100], Step [200/600], d_loss: 0.2597, g_loss: 3.8086, D(x): 0.91, D(G(z)): 0.09
# Epoch [21/100], Step [400/600], d_loss: 0.3407, g_loss: 3.2654, D(x): 0.87, D(G(z)): 0.09
# Epoch [21/100], Step [600/600], d_loss: 0.3067, g_loss: 3.4507, D(x): 0.90, D(G(z)): 0.08
# Saving fake_images-0022.png
# Epoch [22/100], Step [200/600], d_loss: 0.5812, g_loss: 3.9525, D(x): 0.84, D(G(z)): 0.14
# Epoch [22/100], Step [400/600], d_loss: 0.5356, g_loss: 3.2427, D(x): 0.90, D(G(z)): 0.17
# Epoch [22/100], Step [600/600], d_loss: 0.4821, g_loss: 3.2151, D(x): 0.88, D(G(z)): 0.16
# Saving fake_images-0023.png
# Epoch [23/100], Step [200/600], d_loss: 0.6475, g_loss: 2.9283, D(x): 0.81, D(G(z)): 0.16
# Epoch [23/100], Step [400/600], d_loss: 0.3507, g_loss: 3.2920, D(x): 0.91, D(G(z)): 0.13
# Epoch [23/100], Step [600/600], d_loss: 0.5549, g_loss: 2.6324, D(x): 0.84, D(G(z)): 0.16
# Saving fake_images-0024.png
# Epoch [24/100], Step [200/600], d_loss: 0.4966, g_loss: 3.4219, D(x): 0.85, D(G(z)): 0.14
# Epoch [24/100], Step [400/600], d_loss: 0.5917, g_loss: 2.4195, D(x): 0.84, D(G(z)): 0.21
# Epoch [24/100], Step [600/600], d_loss: 0.4642, g_loss: 3.1886, D(x): 0.88, D(G(z)): 0.17
# Saving fake_images-0025.png
# Epoch [25/100], Step [200/600], d_loss: 0.3654, g_loss: 3.8079, D(x): 0.90, D(G(z)): 0.12
# Epoch [25/100], Step [400/600], d_loss: 0.5182, g_loss: 3.2612, D(x): 0.83, D(G(z)): 0.13
# Epoch [25/100], Step [600/600], d_loss: 0.3639, g_loss: 3.3964, D(x): 0.91, D(G(z)): 0.15
# Saving fake_images-0026.png
# Epoch [26/100], Step [200/600], d_loss: 0.6266, g_loss: 3.4541, D(x): 0.88, D(G(z)): 0.21
# Epoch [26/100], Step [400/600], d_loss: 0.3884, g_loss: 3.6706, D(x): 0.92, D(G(z)): 0.18
# Epoch [26/100], Step [600/600], d_loss: 0.5446, g_loss: 3.1894, D(x): 0.86, D(G(z)): 0.17
# Saving fake_images-0027.png
# Epoch [27/100], Step [200/600], d_loss: 0.3408, g_loss: 3.4480, D(x): 0.92, D(G(z)): 0.12
# Epoch [27/100], Step [400/600], d_loss: 0.4205, g_loss: 3.7230, D(x): 0.86, D(G(z)): 0.07
# Epoch [27/100], Step [600/600], d_loss: 0.5416, g_loss: 3.6414, D(x): 0.83, D(G(z)): 0.10
# Saving fake_images-0028.png
# Epoch [28/100], Step [200/600], d_loss: 0.3442, g_loss: 3.5523, D(x): 0.90, D(G(z)): 0.10
# Epoch [28/100], Step [400/600], d_loss: 0.5883, g_loss: 2.9498, D(x): 0.80, D(G(z)): 0.13
# Epoch [28/100], Step [600/600], d_loss: 0.5751, g_loss: 2.9255, D(x): 0.77, D(G(z)): 0.10
# Saving fake_images-0029.png
# Epoch [29/100], Step [200/600], d_loss: 0.4159, g_loss: 3.4916, D(x): 0.87, D(G(z)): 0.13
# Epoch [29/100], Step [400/600], d_loss: 0.4792, g_loss: 3.2882, D(x): 0.87, D(G(z)): 0.14
# Epoch [29/100], Step [600/600], d_loss: 0.6670, g_loss: 2.4750, D(x): 0.83, D(G(z)): 0.21
# Saving fake_images-0030.png
# Epoch [30/100], Step [200/600], d_loss: 0.6499, g_loss: 2.4999, D(x): 0.79, D(G(z)): 0.12
# Epoch [30/100], Step [400/600], d_loss: 0.4863, g_loss: 2.9596, D(x): 0.82, D(G(z)): 0.12
# Epoch [30/100], Step [600/600], d_loss: 0.4367, g_loss: 3.1477, D(x): 0.84, D(G(z)): 0.08
# Saving fake_images-0031.png
# Epoch [31/100], Step [200/600], d_loss: 0.5902, g_loss: 2.6165, D(x): 0.84, D(G(z)): 0.16
# Epoch [31/100], Step [400/600], d_loss: 0.3436, g_loss: 3.4611, D(x): 0.86, D(G(z)): 0.10
# Epoch [31/100], Step [600/600], d_loss: 0.4828, g_loss: 2.8810, D(x): 0.88, D(G(z)): 0.16
# Saving fake_images-0032.png
# Epoch [32/100], Step [200/600], d_loss: 0.4771, g_loss: 2.8058, D(x): 0.90, D(G(z)): 0.22
# Epoch [32/100], Step [400/600], d_loss: 0.7671, g_loss: 2.5488, D(x): 0.78, D(G(z)): 0.21
# Epoch [32/100], Step [600/600], d_loss: 0.5709, g_loss: 2.7041, D(x): 0.82, D(G(z)): 0.18
# Saving fake_images-0033.png
# Epoch [33/100], Step [200/600], d_loss: 0.6909, g_loss: 2.2140, D(x): 0.77, D(G(z)): 0.19
# Epoch [33/100], Step [400/600], d_loss: 0.4394, g_loss: 2.5540, D(x): 0.86, D(G(z)): 0.15
# Epoch [33/100], Step [600/600], d_loss: 0.3633, g_loss: 3.4039, D(x): 0.87, D(G(z)): 0.09
# Saving fake_images-0034.png
# Epoch [34/100], Step [200/600], d_loss: 0.4319, g_loss: 2.6087, D(x): 0.89, D(G(z)): 0.22
# Epoch [34/100], Step [400/600], d_loss: 0.3566, g_loss: 3.7018, D(x): 0.89, D(G(z)): 0.14
# Epoch [34/100], Step [600/600], d_loss: 0.7069, g_loss: 2.6659, D(x): 0.78, D(G(z)): 0.14
# Saving fake_images-0035.png
# Epoch [35/100], Step [200/600], d_loss: 0.7324, g_loss: 3.3487, D(x): 0.75, D(G(z)): 0.09
# Epoch [35/100], Step [400/600], d_loss: 0.5681, g_loss: 2.4488, D(x): 0.76, D(G(z)): 0.10
# Epoch [35/100], Step [600/600], d_loss: 0.4421, g_loss: 2.6703, D(x): 0.88, D(G(z)): 0.16
# Saving fake_images-0036.png
# Epoch [36/100], Step [200/600], d_loss: 0.4748, g_loss: 2.2061, D(x): 0.84, D(G(z)): 0.16
# Epoch [36/100], Step [400/600], d_loss: 0.3918, g_loss: 2.5347, D(x): 0.91, D(G(z)): 0.21
# Epoch [36/100], Step [600/600], d_loss: 0.5910, g_loss: 3.1164, D(x): 0.78, D(G(z)): 0.09
# Saving fake_images-0037.png
# Epoch [37/100], Step [200/600], d_loss: 0.6173, g_loss: 2.9429, D(x): 0.82, D(G(z)): 0.16
# Epoch [37/100], Step [400/600], d_loss: 0.7734, g_loss: 2.3336, D(x): 0.80, D(G(z)): 0.22
# Epoch [37/100], Step [600/600], d_loss: 0.5481, g_loss: 2.4272, D(x): 0.87, D(G(z)): 0.24
# Saving fake_images-0038.png
# Epoch [38/100], Step [200/600], d_loss: 0.6728, g_loss: 2.5063, D(x): 0.84, D(G(z)): 0.22
# Epoch [38/100], Step [400/600], d_loss: 0.5871, g_loss: 2.3229, D(x): 0.83, D(G(z)): 0.21
# Epoch [38/100], Step [600/600], d_loss: 0.7713, g_loss: 1.9338, D(x): 0.81, D(G(z)): 0.29
# Saving fake_images-0039.png
# Epoch [39/100], Step [200/600], d_loss: 0.9001, g_loss: 2.2363, D(x): 0.75, D(G(z)): 0.27
# Epoch [39/100], Step [400/600], d_loss: 0.7327, g_loss: 2.4763, D(x): 0.80, D(G(z)): 0.25
# Epoch [39/100], Step [600/600], d_loss: 0.5795, g_loss: 3.0225, D(x): 0.82, D(G(z)): 0.18
# Saving fake_images-0040.png
# Epoch [40/100], Step [200/600], d_loss: 0.6455, g_loss: 2.2909, D(x): 0.83, D(G(z)): 0.22
# Epoch [40/100], Step [400/600], d_loss: 0.5003, g_loss: 2.3833, D(x): 0.85, D(G(z)): 0.20
# Epoch [40/100], Step [600/600], d_loss: 0.8672, g_loss: 3.0270, D(x): 0.77, D(G(z)): 0.26
# Saving fake_images-0041.png
# Epoch [41/100], Step [200/600], d_loss: 0.5590, g_loss: 2.5473, D(x): 0.81, D(G(z)): 0.20
# Epoch [41/100], Step [400/600], d_loss: 0.5136, g_loss: 2.2320, D(x): 0.83, D(G(z)): 0.17
# Epoch [41/100], Step [600/600], d_loss: 0.6927, g_loss: 2.1911, D(x): 0.88, D(G(z)): 0.32
# Saving fake_images-0042.png
# Epoch [42/100], Step [200/600], d_loss: 0.9695, g_loss: 2.6012, D(x): 0.66, D(G(z)): 0.17
# Epoch [42/100], Step [400/600], d_loss: 0.4925, g_loss: 2.3393, D(x): 0.80, D(G(z)): 0.14
# Epoch [42/100], Step [600/600], d_loss: 0.7745, g_loss: 2.4217, D(x): 0.76, D(G(z)): 0.21
# Saving fake_images-0043.png
# Epoch [43/100], Step [200/600], d_loss: 0.8201, g_loss: 3.1919, D(x): 0.69, D(G(z)): 0.11
# Epoch [43/100], Step [400/600], d_loss: 0.4838, g_loss: 2.8426, D(x): 0.86, D(G(z)): 0.18
# Epoch [43/100], Step [600/600], d_loss: 0.3921, g_loss: 2.3764, D(x): 0.86, D(G(z)): 0.15
# Saving fake_images-0044.png
# Epoch [44/100], Step [200/600], d_loss: 0.6247, g_loss: 2.6781, D(x): 0.81, D(G(z)): 0.19
# Epoch [44/100], Step [400/600], d_loss: 0.5781, g_loss: 2.3677, D(x): 0.77, D(G(z)): 0.16
# Epoch [44/100], Step [600/600], d_loss: 0.5691, g_loss: 2.4511, D(x): 0.80, D(G(z)): 0.16
# Saving fake_images-0045.png
# Epoch [45/100], Step [200/600], d_loss: 0.6430, g_loss: 1.9940, D(x): 0.81, D(G(z)): 0.22
# Epoch [45/100], Step [400/600], d_loss: 0.6164, g_loss: 2.3404, D(x): 0.83, D(G(z)): 0.23
# Epoch [45/100], Step [600/600], d_loss: 0.6746, g_loss: 2.3283, D(x): 0.83, D(G(z)): 0.26
# Saving fake_images-0046.png
# Epoch [46/100], Step [200/600], d_loss: 0.9224, g_loss: 2.0716, D(x): 0.69, D(G(z)): 0.19
# Epoch [46/100], Step [400/600], d_loss: 0.6991, g_loss: 1.8160, D(x): 0.85, D(G(z)): 0.31
# Epoch [46/100], Step [600/600], d_loss: 1.0418, g_loss: 1.9154, D(x): 0.63, D(G(z)): 0.19
# Saving fake_images-0047.png
# Epoch [47/100], Step [200/600], d_loss: 0.8107, g_loss: 2.3827, D(x): 0.77, D(G(z)): 0.25
# Epoch [47/100], Step [400/600], d_loss: 0.7179, g_loss: 1.8697, D(x): 0.78, D(G(z)): 0.21
# Epoch [47/100], Step [600/600], d_loss: 0.8207, g_loss: 2.5227, D(x): 0.76, D(G(z)): 0.24
# Saving fake_images-0048.png
# Epoch [48/100], Step [200/600], d_loss: 0.5997, g_loss: 2.2962, D(x): 0.84, D(G(z)): 0.26
# Epoch [48/100], Step [400/600], d_loss: 0.4859, g_loss: 2.8513, D(x): 0.82, D(G(z)): 0.14
# Epoch [48/100], Step [600/600], d_loss: 0.8942, g_loss: 2.2145, D(x): 0.77, D(G(z)): 0.31
# Saving fake_images-0049.png
# Epoch [49/100], Step [200/600], d_loss: 0.8335, g_loss: 2.5182, D(x): 0.74, D(G(z)): 0.19
# Epoch [49/100], Step [400/600], d_loss: 1.0526, g_loss: 1.6588, D(x): 0.73, D(G(z)): 0.35
# Epoch [49/100], Step [600/600], d_loss: 0.6368, g_loss: 2.2704, D(x): 0.78, D(G(z)): 0.18
# Saving fake_images-0050.png
# Epoch [50/100], Step [200/600], d_loss: 0.7009, g_loss: 2.1902, D(x): 0.74, D(G(z)): 0.20
# Epoch [50/100], Step [400/600], d_loss: 0.8902, g_loss: 2.4715, D(x): 0.70, D(G(z)): 0.19
# Epoch [50/100], Step [600/600], d_loss: 0.5509, g_loss: 2.2067, D(x): 0.83, D(G(z)): 0.22
# Saving fake_images-0051.png
# Epoch [51/100], Step [200/600], d_loss: 0.5796, g_loss: 2.5328, D(x): 0.79, D(G(z)): 0.17
# Epoch [51/100], Step [400/600], d_loss: 0.9166, g_loss: 2.0049, D(x): 0.81, D(G(z)): 0.31
# Epoch [51/100], Step [600/600], d_loss: 0.6725, g_loss: 2.3016, D(x): 0.74, D(G(z)): 0.14
# Saving fake_images-0052.png
# Epoch [52/100], Step [200/600], d_loss: 0.7006, g_loss: 2.4732, D(x): 0.79, D(G(z)): 0.25
# Epoch [52/100], Step [400/600], d_loss: 0.7317, g_loss: 2.6742, D(x): 0.79, D(G(z)): 0.23
# Epoch [52/100], Step [600/600], d_loss: 0.7662, g_loss: 2.5698, D(x): 0.70, D(G(z)): 0.22
# Saving fake_images-0053.png
# Epoch [53/100], Step [200/600], d_loss: 0.6531, g_loss: 2.4786, D(x): 0.73, D(G(z)): 0.13
# Epoch [53/100], Step [400/600], d_loss: 0.9050, g_loss: 1.9526, D(x): 0.82, D(G(z)): 0.38
# Epoch [53/100], Step [600/600], d_loss: 0.7994, g_loss: 2.1261, D(x): 0.74, D(G(z)): 0.23
# Saving fake_images-0054.png
# Epoch [54/100], Step [200/600], d_loss: 0.6365, g_loss: 2.5955, D(x): 0.82, D(G(z)): 0.24
# Epoch [54/100], Step [400/600], d_loss: 0.6179, g_loss: 2.9378, D(x): 0.84, D(G(z)): 0.25
# Epoch [54/100], Step [600/600], d_loss: 0.7969, g_loss: 2.8235, D(x): 0.71, D(G(z)): 0.20
# Saving fake_images-0055.png
# Epoch [55/100], Step [200/600], d_loss: 0.6325, g_loss: 2.1674, D(x): 0.79, D(G(z)): 0.21
# Epoch [55/100], Step [400/600], d_loss: 0.7860, g_loss: 1.8930, D(x): 0.81, D(G(z)): 0.30
# Epoch [55/100], Step [600/600], d_loss: 0.6794, g_loss: 2.8878, D(x): 0.72, D(G(z)): 0.15
# Saving fake_images-0056.png
# Epoch [56/100], Step [200/600], d_loss: 0.6413, g_loss: 2.1888, D(x): 0.79, D(G(z)): 0.23
# Epoch [56/100], Step [400/600], d_loss: 0.8579, g_loss: 2.1117, D(x): 0.75, D(G(z)): 0.22
# Epoch [56/100], Step [600/600], d_loss: 0.6993, g_loss: 2.4076, D(x): 0.85, D(G(z)): 0.31
# Saving fake_images-0057.png
# Epoch [57/100], Step [200/600], d_loss: 0.7644, g_loss: 2.4533, D(x): 0.77, D(G(z)): 0.23
# Epoch [57/100], Step [400/600], d_loss: 0.5966, g_loss: 2.4565, D(x): 0.92, D(G(z)): 0.30
# Epoch [57/100], Step [600/600], d_loss: 0.7533, g_loss: 2.2347, D(x): 0.81, D(G(z)): 0.26
# Saving fake_images-0058.png
# Epoch [58/100], Step [200/600], d_loss: 0.7777, g_loss: 2.0449, D(x): 0.79, D(G(z)): 0.26
# Epoch [58/100], Step [400/600], d_loss: 0.8677, g_loss: 1.8500, D(x): 0.77, D(G(z)): 0.32
# Epoch [58/100], Step [600/600], d_loss: 0.7898, g_loss: 2.0324, D(x): 0.78, D(G(z)): 0.29
# Saving fake_images-0059.png
# Epoch [59/100], Step [200/600], d_loss: 0.8383, g_loss: 1.8337, D(x): 0.73, D(G(z)): 0.26
# Epoch [59/100], Step [400/600], d_loss: 0.6154, g_loss: 2.2603, D(x): 0.77, D(G(z)): 0.19
# Epoch [59/100], Step [600/600], d_loss: 0.9014, g_loss: 2.1275, D(x): 0.76, D(G(z)): 0.31
# Saving fake_images-0060.png
# Epoch [60/100], Step [200/600], d_loss: 0.7940, g_loss: 1.5051, D(x): 0.82, D(G(z)): 0.31
# Epoch [60/100], Step [400/600], d_loss: 0.6994, g_loss: 2.2865, D(x): 0.80, D(G(z)): 0.25
# Epoch [60/100], Step [600/600], d_loss: 0.6187, g_loss: 2.9023, D(x): 0.74, D(G(z)): 0.09
# Saving fake_images-0061.png
# Epoch [61/100], Step [200/600], d_loss: 1.0070, g_loss: 1.3498, D(x): 0.70, D(G(z)): 0.26
# Epoch [61/100], Step [400/600], d_loss: 0.6420, g_loss: 2.2561, D(x): 0.85, D(G(z)): 0.28
# Epoch [61/100], Step [600/600], d_loss: 0.6182, g_loss: 2.2591, D(x): 0.79, D(G(z)): 0.21
# Saving fake_images-0062.png
# Epoch [62/100], Step [200/600], d_loss: 0.6511, g_loss: 2.7363, D(x): 0.80, D(G(z)): 0.25
# Epoch [62/100], Step [400/600], d_loss: 0.4263, g_loss: 3.1096, D(x): 0.86, D(G(z)): 0.15
# Epoch [62/100], Step [600/600], d_loss: 0.9901, g_loss: 1.6438, D(x): 0.69, D(G(z)): 0.23
# Saving fake_images-0063.png
# Epoch [63/100], Step [200/600], d_loss: 1.0399, g_loss: 2.3128, D(x): 0.68, D(G(z)): 0.30
# Epoch [63/100], Step [400/600], d_loss: 0.7561, g_loss: 2.5527, D(x): 0.71, D(G(z)): 0.18
# Epoch [63/100], Step [600/600], d_loss: 0.7744, g_loss: 2.1310, D(x): 0.72, D(G(z)): 0.23
# Saving fake_images-0064.png
# Epoch [64/100], Step [200/600], d_loss: 0.6327, g_loss: 2.9765, D(x): 0.78, D(G(z)): 0.19
# Epoch [64/100], Step [400/600], d_loss: 0.7518, g_loss: 2.1247, D(x): 0.75, D(G(z)): 0.24
# Epoch [64/100], Step [600/600], d_loss: 1.1552, g_loss: 1.5269, D(x): 0.69, D(G(z)): 0.39
# Saving fake_images-0065.png
# Epoch [65/100], Step [200/600], d_loss: 0.7255, g_loss: 2.3105, D(x): 0.82, D(G(z)): 0.31
# Epoch [65/100], Step [400/600], d_loss: 0.7298, g_loss: 2.3869, D(x): 0.77, D(G(z)): 0.25
# Epoch [65/100], Step [600/600], d_loss: 0.7682, g_loss: 2.1892, D(x): 0.72, D(G(z)): 0.20
# Saving fake_images-0066.png
# Epoch [66/100], Step [200/600], d_loss: 0.7232, g_loss: 1.5338, D(x): 0.79, D(G(z)): 0.22
# Epoch [66/100], Step [400/600], d_loss: 0.8140, g_loss: 2.9895, D(x): 0.65, D(G(z)): 0.13
# Epoch [66/100], Step [600/600], d_loss: 0.8333, g_loss: 2.1809, D(x): 0.73, D(G(z)): 0.24
# Saving fake_images-0067.png
# Epoch [67/100], Step [200/600], d_loss: 0.6303, g_loss: 2.0574, D(x): 0.73, D(G(z)): 0.18
# Epoch [67/100], Step [400/600], d_loss: 0.6727, g_loss: 2.1733, D(x): 0.77, D(G(z)): 0.24
# Epoch [67/100], Step [600/600], d_loss: 0.9303, g_loss: 2.0655, D(x): 0.78, D(G(z)): 0.36
# Saving fake_images-0068.png
# Epoch [68/100], Step [200/600], d_loss: 0.6759, g_loss: 2.5523, D(x): 0.75, D(G(z)): 0.19
# Epoch [68/100], Step [400/600], d_loss: 0.7394, g_loss: 2.3937, D(x): 0.79, D(G(z)): 0.25
# Epoch [68/100], Step [600/600], d_loss: 0.6874, g_loss: 2.0704, D(x): 0.79, D(G(z)): 0.28
# Saving fake_images-0069.png
# Epoch [69/100], Step [200/600], d_loss: 0.9155, g_loss: 2.4692, D(x): 0.70, D(G(z)): 0.24
# Epoch [69/100], Step [400/600], d_loss: 0.8395, g_loss: 2.0497, D(x): 0.71, D(G(z)): 0.19
# Epoch [69/100], Step [600/600], d_loss: 0.9321, g_loss: 1.8671, D(x): 0.68, D(G(z)): 0.20
# Saving fake_images-0070.png
# Epoch [70/100], Step [200/600], d_loss: 0.8741, g_loss: 2.6945, D(x): 0.75, D(G(z)): 0.27
# Epoch [70/100], Step [400/600], d_loss: 0.9898, g_loss: 1.6076, D(x): 0.72, D(G(z)): 0.32
# Epoch [70/100], Step [600/600], d_loss: 0.8400, g_loss: 1.8083, D(x): 0.83, D(G(z)): 0.37
# Saving fake_images-0071.png
# Epoch [71/100], Step [200/600], d_loss: 0.8739, g_loss: 1.8153, D(x): 0.76, D(G(z)): 0.30
# Epoch [71/100], Step [400/600], d_loss: 0.7762, g_loss: 1.7846, D(x): 0.76, D(G(z)): 0.23
# Epoch [71/100], Step [600/600], d_loss: 1.0241, g_loss: 1.6947, D(x): 0.77, D(G(z)): 0.40
# Saving fake_images-0072.png
# Epoch [72/100], Step [200/600], d_loss: 0.5382, g_loss: 2.4547, D(x): 0.83, D(G(z)): 0.19
# Epoch [72/100], Step [400/600], d_loss: 0.8442, g_loss: 2.2777, D(x): 0.73, D(G(z)): 0.26
# Epoch [72/100], Step [600/600], d_loss: 0.7779, g_loss: 2.2059, D(x): 0.75, D(G(z)): 0.21
# Saving fake_images-0073.png
# Epoch [73/100], Step [200/600], d_loss: 0.6605, g_loss: 2.0318, D(x): 0.78, D(G(z)): 0.22
# Epoch [73/100], Step [400/600], d_loss: 0.4999, g_loss: 2.6359, D(x): 0.81, D(G(z)): 0.13
# Epoch [73/100], Step [600/600], d_loss: 0.5901, g_loss: 2.6779, D(x): 0.75, D(G(z)): 0.15
# Saving fake_images-0074.png
# Epoch [74/100], Step [200/600], d_loss: 0.8457, g_loss: 2.2814, D(x): 0.67, D(G(z)): 0.16
# Epoch [74/100], Step [400/600], d_loss: 0.8828, g_loss: 2.0546, D(x): 0.74, D(G(z)): 0.28
# Epoch [74/100], Step [600/600], d_loss: 0.8422, g_loss: 1.6033, D(x): 0.74, D(G(z)): 0.27
# Saving fake_images-0075.png
# Epoch [75/100], Step [200/600], d_loss: 0.6564, g_loss: 1.4368, D(x): 0.80, D(G(z)): 0.25
# Epoch [75/100], Step [400/600], d_loss: 0.7933, g_loss: 2.4183, D(x): 0.78, D(G(z)): 0.28
# Epoch [75/100], Step [600/600], d_loss: 0.8801, g_loss: 1.9429, D(x): 0.71, D(G(z)): 0.25
# Saving fake_images-0076.png
# Epoch [76/100], Step [200/600], d_loss: 0.6863, g_loss: 1.8496, D(x): 0.80, D(G(z)): 0.24
# Epoch [76/100], Step [400/600], d_loss: 1.0811, g_loss: 1.7817, D(x): 0.69, D(G(z)): 0.32
# Epoch [76/100], Step [600/600], d_loss: 0.7576, g_loss: 1.9610, D(x): 0.77, D(G(z)): 0.28
# Saving fake_images-0077.png
# Epoch [77/100], Step [200/600], d_loss: 0.6598, g_loss: 1.6075, D(x): 0.77, D(G(z)): 0.22
# Epoch [77/100], Step [400/600], d_loss: 0.7908, g_loss: 1.8537, D(x): 0.73, D(G(z)): 0.23
# Epoch [77/100], Step [600/600], d_loss: 0.6888, g_loss: 2.4396, D(x): 0.73, D(G(z)): 0.17
# Saving fake_images-0078.png
# Epoch [78/100], Step [200/600], d_loss: 0.9346, g_loss: 1.8933, D(x): 0.65, D(G(z)): 0.21
# Epoch [78/100], Step [400/600], d_loss: 0.9857, g_loss: 1.7813, D(x): 0.70, D(G(z)): 0.31
# Epoch [78/100], Step [600/600], d_loss: 0.6151, g_loss: 2.0562, D(x): 0.81, D(G(z)): 0.24
# Saving fake_images-0079.png
# Epoch [79/100], Step [200/600], d_loss: 0.8251, g_loss: 1.9129, D(x): 0.69, D(G(z)): 0.24
# Epoch [79/100], Step [400/600], d_loss: 0.9172, g_loss: 1.9434, D(x): 0.79, D(G(z)): 0.35
# Epoch [79/100], Step [600/600], d_loss: 0.7431, g_loss: 1.7700, D(x): 0.77, D(G(z)): 0.28
# Saving fake_images-0080.png
# Epoch [80/100], Step [200/600], d_loss: 0.7426, g_loss: 1.9904, D(x): 0.78, D(G(z)): 0.27
# Epoch [80/100], Step [400/600], d_loss: 0.9218, g_loss: 1.9468, D(x): 0.71, D(G(z)): 0.28
# Epoch [80/100], Step [600/600], d_loss: 0.7601, g_loss: 2.0384, D(x): 0.79, D(G(z)): 0.27
# Saving fake_images-0081.png
# Epoch [81/100], Step [200/600], d_loss: 0.7163, g_loss: 2.1119, D(x): 0.76, D(G(z)): 0.20
# Epoch [81/100], Step [400/600], d_loss: 0.9734, g_loss: 2.3009, D(x): 0.70, D(G(z)): 0.26
# Epoch [81/100], Step [600/600], d_loss: 0.8526, g_loss: 2.4811, D(x): 0.72, D(G(z)): 0.21
# Saving fake_images-0082.png
# Epoch [82/100], Step [200/600], d_loss: 0.7492, g_loss: 2.0089, D(x): 0.82, D(G(z)): 0.32
# Epoch [82/100], Step [400/600], d_loss: 0.5792, g_loss: 2.2140, D(x): 0.83, D(G(z)): 0.22
# Epoch [82/100], Step [600/600], d_loss: 0.6988, g_loss: 2.0210, D(x): 0.77, D(G(z)): 0.23
# Saving fake_images-0083.png
# Epoch [83/100], Step [200/600], d_loss: 0.7357, g_loss: 2.0272, D(x): 0.76, D(G(z)): 0.25
# Epoch [83/100], Step [400/600], d_loss: 0.7434, g_loss: 2.0031, D(x): 0.81, D(G(z)): 0.31
# Epoch [83/100], Step [600/600], d_loss: 0.7405, g_loss: 2.2667, D(x): 0.74, D(G(z)): 0.23
# Saving fake_images-0084.png
# Epoch [84/100], Step [200/600], d_loss: 0.8684, g_loss: 2.2635, D(x): 0.72, D(G(z)): 0.24
# Epoch [84/100], Step [400/600], d_loss: 0.8387, g_loss: 2.2964, D(x): 0.80, D(G(z)): 0.34
# Epoch [84/100], Step [600/600], d_loss: 0.5307, g_loss: 1.7215, D(x): 0.87, D(G(z)): 0.24
# Saving fake_images-0085.png
# Epoch [85/100], Step [200/600], d_loss: 0.9076, g_loss: 1.9728, D(x): 0.74, D(G(z)): 0.31
# Epoch [85/100], Step [400/600], d_loss: 0.7374, g_loss: 2.1766, D(x): 0.74, D(G(z)): 0.23
# Epoch [85/100], Step [600/600], d_loss: 0.5467, g_loss: 2.5879, D(x): 0.83, D(G(z)): 0.22
# Saving fake_images-0086.png
# Epoch [86/100], Step [200/600], d_loss: 0.7753, g_loss: 2.1692, D(x): 0.73, D(G(z)): 0.22
# Epoch [86/100], Step [400/600], d_loss: 0.9241, g_loss: 1.4088, D(x): 0.76, D(G(z)): 0.36
# Epoch [86/100], Step [600/600], d_loss: 0.8570, g_loss: 1.7784, D(x): 0.72, D(G(z)): 0.26
# Saving fake_images-0087.png
# Epoch [87/100], Step [200/600], d_loss: 0.7551, g_loss: 1.7671, D(x): 0.75, D(G(z)): 0.25
# Epoch [87/100], Step [400/600], d_loss: 1.2069, g_loss: 2.4482, D(x): 0.63, D(G(z)): 0.28
# Epoch [87/100], Step [600/600], d_loss: 0.8408, g_loss: 1.6861, D(x): 0.75, D(G(z)): 0.26
# Saving fake_images-0088.png
# Epoch [88/100], Step [200/600], d_loss: 1.0334, g_loss: 1.7775, D(x): 0.70, D(G(z)): 0.32
# Epoch [88/100], Step [400/600], d_loss: 0.8396, g_loss: 1.9791, D(x): 0.71, D(G(z)): 0.24
# Epoch [88/100], Step [600/600], d_loss: 0.7516, g_loss: 2.0466, D(x): 0.77, D(G(z)): 0.25
# Saving fake_images-0089.png
# Epoch [89/100], Step [200/600], d_loss: 0.8304, g_loss: 2.4973, D(x): 0.70, D(G(z)): 0.22
# Epoch [89/100], Step [400/600], d_loss: 0.6978, g_loss: 1.5407, D(x): 0.75, D(G(z)): 0.22
# Epoch [89/100], Step [600/600], d_loss: 0.7423, g_loss: 1.6269, D(x): 0.76, D(G(z)): 0.26
# Saving fake_images-0090.png
# Epoch [90/100], Step [200/600], d_loss: 0.8715, g_loss: 1.9518, D(x): 0.69, D(G(z)): 0.24
# Epoch [90/100], Step [400/600], d_loss: 0.9579, g_loss: 1.6206, D(x): 0.72, D(G(z)): 0.33
# Epoch [90/100], Step [600/600], d_loss: 0.9223, g_loss: 1.9972, D(x): 0.70, D(G(z)): 0.24
# Saving fake_images-0091.png
# Epoch [91/100], Step [200/600], d_loss: 0.6692, g_loss: 1.9491, D(x): 0.80, D(G(z)): 0.26
# Epoch [91/100], Step [400/600], d_loss: 0.8863, g_loss: 1.9498, D(x): 0.72, D(G(z)): 0.28
# Epoch [91/100], Step [600/600], d_loss: 0.7999, g_loss: 1.7252, D(x): 0.76, D(G(z)): 0.28
# Saving fake_images-0092.png
# Epoch [92/100], Step [200/600], d_loss: 0.8087, g_loss: 2.0979, D(x): 0.74, D(G(z)): 0.25
# Epoch [92/100], Step [400/600], d_loss: 0.7610, g_loss: 2.2875, D(x): 0.72, D(G(z)): 0.21
# Epoch [92/100], Step [600/600], d_loss: 0.6964, g_loss: 1.7718, D(x): 0.77, D(G(z)): 0.26
# Saving fake_images-0093.png
# Epoch [93/100], Step [200/600], d_loss: 0.9674, g_loss: 1.6223, D(x): 0.76, D(G(z)): 0.36
# Epoch [93/100], Step [400/600], d_loss: 0.8060, g_loss: 1.9200, D(x): 0.69, D(G(z)): 0.24
# Epoch [93/100], Step [600/600], d_loss: 0.7465, g_loss: 2.1774, D(x): 0.76, D(G(z)): 0.27
# Saving fake_images-0094.png
# Epoch [94/100], Step [200/600], d_loss: 0.9655, g_loss: 1.9511, D(x): 0.67, D(G(z)): 0.24
# Epoch [94/100], Step [400/600], d_loss: 0.6988, g_loss: 1.9716, D(x): 0.75, D(G(z)): 0.23
# Epoch [94/100], Step [600/600], d_loss: 0.8064, g_loss: 1.9058, D(x): 0.82, D(G(z)): 0.36
# Saving fake_images-0095.png
# Epoch [95/100], Step [200/600], d_loss: 0.8293, g_loss: 2.4791, D(x): 0.74, D(G(z)): 0.25
# Epoch [95/100], Step [400/600], d_loss: 0.9766, g_loss: 1.8126, D(x): 0.75, D(G(z)): 0.35
# Epoch [95/100], Step [600/600], d_loss: 1.0176, g_loss: 2.2038, D(x): 0.80, D(G(z)): 0.35
# Saving fake_images-0096.png
# Epoch [96/100], Step [200/600], d_loss: 1.1240, g_loss: 1.3135, D(x): 0.71, D(G(z)): 0.40
# Epoch [96/100], Step [400/600], d_loss: 0.7597, g_loss: 1.8922, D(x): 0.76, D(G(z)): 0.22
# Epoch [96/100], Step [600/600], d_loss: 1.0198, g_loss: 1.7263, D(x): 0.65, D(G(z)): 0.27
# Saving fake_images-0097.png
# Epoch [97/100], Step [200/600], d_loss: 1.1359, g_loss: 1.6894, D(x): 0.75, D(G(z)): 0.39
# Epoch [97/100], Step [400/600], d_loss: 0.8674, g_loss: 1.6004, D(x): 0.73, D(G(z)): 0.28
# Epoch [97/100], Step [600/600], d_loss: 0.9015, g_loss: 1.6741, D(x): 0.68, D(G(z)): 0.25
# Saving fake_images-0098.png
# Epoch [98/100], Step [200/600], d_loss: 0.8336, g_loss: 1.8066, D(x): 0.77, D(G(z)): 0.32
# Epoch [98/100], Step [400/600], d_loss: 0.7211, g_loss: 1.7939, D(x): 0.77, D(G(z)): 0.27
# Epoch [98/100], Step [600/600], d_loss: 0.7053, g_loss: 1.7407, D(x): 0.79, D(G(z)): 0.29
# Saving fake_images-0099.png
# Epoch [99/100], Step [200/600], d_loss: 0.6755, g_loss: 1.7937, D(x): 0.76, D(G(z)): 0.24
# Epoch [99/100], Step [400/600], d_loss: 1.0583, g_loss: 1.3714, D(x): 0.64, D(G(z)): 0.29
# Epoch [99/100], Step [600/600], d_loss: 0.8185, g_loss: 2.0149, D(x): 0.73, D(G(z)): 0.26
# Saving fake_images-0100.png
# CPU times: user 19min 28s, sys: 9.66 s, total: 19min 38s
# Wall time: 19min 29s

# %%
# Save the model checkpoints 
torch.save(Generator_model.state_dict(), 'G.ckpt')
torch.save(Discriminator_model.state_dict(), 'D.ckpt')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %%
import glob
from PIL import Image

# filepaths
fp_in = "samples/fake_images-*.png"
fp_out = "samples/fake_image.gif"

imgs = (Image.open(f) for f in sorted(glob.glob(fp_in)))
img = next(imgs)  # extract first image from iterator
img.save(fp=fp_out, format='GIF', append_images=imgs,
         save_all=True, duration=200, loop=0)

# %%
from IPython.display import Image

# %%
Image("samples/real_images.png")

# %%
fake_fname = 'fake_images-{0:0=4d}.png'.format(num_epochs)
Image(os.path.join(sample_dir, fake_fname))
